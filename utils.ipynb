# %%
from langchain_community.utilities.sql_database import SQLDatabase
import pandas as pd
db = SQLDatabase.from_uri("sqlite:///chinook.db")
print(db.get_usable_table_names())
import json
# Out:
# ['albums', 'artists', 'customers', 'employees', 'genres', 'invoice_items', 'invoices', 'media_types', 'playlist_track', 'playlists', 'tracks']

# %%
query = "SELECT * FROM customers LIMIT 15;"
# Use the get_connection method to access the underlying connection
with db._engine.connect() as conn:
    df = pd.read_sql_query(query, conn)
df  # Display the DataFrame
# Out:
#     CustomerId  FirstName     LastName  \
# 0            1       Luís    Gonçalves
# 1            2     Leonie       Köhler
# 2            3   François     Tremblay
# 3            4      Bjørn       Hansen
# 4            5  František  Wichterlová
# 5            6     Helena         Holý
# 6            7     Astrid       Gruber
# 7            8       Daan      Peeters
# 8            9       Kara      Nielsen
# 9           10    Eduardo      Martins
# 10          11  Alexandre        Rocha
# 11          12    Roberto      Almeida
# 12          13   Fernanda        Ramos
# 13          14       Mark      Philips
# 14          15   Jennifer     Peterson
#
#                                              Company  \
# 0   Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                   JetBrains s.r.o.
# ...

# %%
query = "SELECT * FROM artists LIMIT 5;"
# Use the get_connection method to access the underlying connection
with db._engine.connect() as conn:
    df = pd.read_sql_query(query, conn)
df  # Display the DataFrame
# Out:
#    ArtistId               Name
# 0         1              AC/DC
# 1         2             Accept
# 2         3          Aerosmith
# 3         4  Alanis Morissette
# 4         5    Alice In Chains

# %%
query = "SELECT * FROM tracks WHERE Name='Santana Jam';"
# Use the get_connection method to access the underlying connection
with db._engine.connect() as conn:
    df = pd.read_sql_query(query, conn)
df
# Out:
#    TrackId         Name  AlbumId  MediaTypeId  GenreId        Composer  \
# 0     2427  Santana Jam      197            1        1  Carlos Santana
#
#    Milliseconds     Bytes  UnitPrice
# 0        882834  29207100       0.99

# %%
query = "SELECT * FROM albums LIMIT 5;"
# Use the get_connection method to access the underlying connection
with db._engine.connect() as conn:
    df = pd.read_sql_query(query, conn)
df
# Out:
#    AlbumId                                  Title  ArtistId
# 0        1  For Those About To Rock We Salute You         1
# 1        2                      Balls to the Wall         2
# 2        3                      Restless and Wild         2
# 3        4                      Let There Be Rock         1
# 4        5                               Big Ones         3

# %%
query = "SELECT * FROM genres LIMIT 5;"
# Use the get_connection method to access the underlying connection
with db._engine.connect() as conn:
    df = pd.read_sql_query(query, conn)
df
# Out:
#    GenreId                Name
# 0        1                Rock
# 1        2                Jazz
# 2        3               Metal
# 3        4  Alternative & Punk
# 4        5       Rock And Roll

# %% [markdown]
# <h1> User Info </h1>

# %%
query = "SELECT * FROM customers LIMIT 10;"
# Use the get_connection method to access the underlying connection
with db._engine.connect() as conn:
    df = pd.read_sql_query(query, conn)
df  # Display the DataFrame
df.columns.tolist()
# Out:
# ['CustomerId',
#  'FirstName',
#  'LastName',
#  'Company',
#  'Address',
#  'City',
#  'State',
#  'Country',
#  'PostalCode',
#  'Phone',
#  'Fax',
#  'Email',
#  'SupportRepId']

# %%
first_name = 'Astrid'
last_name = 'Gruber'
employees = db.run(
    f"""
    SELECT * FROM customers 
    WHERE FirstName='{first_name}' AND LastName='{last_name}'
"""
)
employees
employee_id = int(employees.strip("[]() ").split(',')[0])
employee_id
# Out:
# 7

# %%
query = "SELECT * FROM artists LIMIT 5;"
# Use the get_connection method to access the underlying connection
with db._engine.connect() as conn:
    df = pd.read_sql_query(query, conn)
df  # Display the DataFrame
# Out:
#    ArtistId               Name
# 0         1              AC/DC
# 1         2             Accept
# 2         3          Aerosmith
# 3         4  Alanis Morissette
# 4         5    Alice In Chains

# %%
query = "SELECT * FROM employees;"
# Use the get_connection method to access the underlying connection
with db._engine.connect() as conn:
    df = pd.read_sql_query(query, conn)
df
# Out:
#    EmployeeId  LastName FirstName                Title  ReportsTo  \
# 0           1     Adams    Andrew      General Manager        NaN
# 1           2   Edwards     Nancy        Sales Manager        1.0
# 2           3   Peacock      Jane  Sales Support Agent        2.0
# 3           4      Park  Margaret  Sales Support Agent        2.0
# 4           5   Johnson     Steve  Sales Support Agent        2.0
# 5           6  Mitchell   Michael           IT Manager        1.0
# 6           7      King    Robert             IT Staff        6.0
# 7           8  Callahan     Laura             IT Staff        6.0
#
#              BirthDate             HireDate                      Address  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00             683 10 Street SW
# ...

# %%
query = "SELECT * FROM media_types LIMIT 5;"
# Use the get_connection method to access the underlying connection
with db._engine.connect() as conn:
    df = pd.read_sql_query(query, conn)
df
# Out:
#    MediaTypeId                         Name
# 0            1              MPEG audio file
# 1            2     Protected AAC audio file
# 2            3  Protected MPEG-4 video file
# 3            4     Purchased AAC audio file
# 4            5               AAC audio file

# %%
query = "SELECT * FROM invoices LIMIT 5;"
# Use the get_connection method to access the underlying connection
with db._engine.connect() as conn:
    df = pd.read_sql_query(query, conn)
df
# Out:
#    InvoiceId  CustomerId          InvoiceDate           BillingAddress  \
# 0          1           2  2009-01-01 00:00:00  Theodor-Heuss-Straße 34
# 1          2           4  2009-01-02 00:00:00         Ullevålsveien 14
# 2          3           8  2009-01-03 00:00:00          Grétrystraat 63
# 3          4          14  2009-01-06 00:00:00           8210 111 ST NW
# 4          5          23  2009-01-11 00:00:00          69 Salem Street
#
#   BillingCity BillingState BillingCountry BillingPostalCode  Total
# 0   Stuttgart         None        Germany             70174   1.98
# 1        Oslo         None         Norway              0171   3.96
# 2    Brussels         None        Belgium              1000   5.94
# 3    Edmonton           AB         Canada           T6G 2C7   8.91
# 4      Boston           MA            USA              2113  13.86

# %%
invoice_info = db.run(
    f"SELECT CustomerId FROM invoices WHERE InvoiceId = {89};"
)
info_str = invoice_info.strip("[]() ")
info_str = info_str.replace(",", "")  # remove any trailing commas
inv_customer_id = int(info_str)
inv_customer_id
# Out:
# 7

# %%
query = f"""
    SELECT invoice_items.*, tracks.Name as TrackName
    FROM invoice_items
    JOIN tracks ON invoice_items.TrackId = tracks.TrackId
    WHERE InvoiceId = {89};
"""

with db._engine.connect() as conn:
    df = pd.read_sql_query(query, conn)
# Parse the line item data

df
# Out:
#     InvoiceLineId  InvoiceId  TrackId  UnitPrice  Quantity  \
# 0             478         89     2883       1.99         1
# 1             479         89     2892       1.99         1
# 2             480         89     2901       1.99         1
# 3             481         89     2910       1.99         1
# 4             482         89     2919       1.99         1
# 5             483         89     2928       0.99         1
# 6             484         89     2937       0.99         1
# 7             485         89     2946       0.99         1
# 8             486         89     2955       0.99         1
# 9             487         89     2964       0.99         1
# 10            488         89     2973       0.99         1
# 11            489         89     2982       0.99         1
# 12            490         89     2991       0.99         1
# 13            491         89     3000       0.99         1
# 14           2241         89     2964      -0.99         1
#
# ...

# %%
query = "SELECT * FROM invoice_items LIMIT 5;"
# Use the get_connection method to access the underlying connection
with db._engine.connect() as conn:
    df = pd.read_sql_query(query, conn)
df
# Out:
#    InvoiceLineId  InvoiceId  TrackId  UnitPrice  Quantity
# 0              1          1        2       0.99         1
# 1              2          1        4       0.99         1
# 2              3          2        6       0.99         1
# 3              4          2        8       0.99         1
# 4              5          2       10       0.99         1

# %%
query = "SELECT * FROM tracks LIMIT 5;"
# Use the get_connection method to access the underlying connection
with db._engine.connect() as conn:
    df = pd.read_sql_query(query, conn)
df
# Out:
#    TrackId                                     Name  AlbumId  MediaTypeId  \
# 0        1  For Those About To Rock (We Salute You)        1            1
# 1        2                        Balls to the Wall        2            2
# 2        3                          Fast As a Shark        3            2
# 3        4                        Restless and Wild        3            2
# 4        5                     Princess of the Dawn        3            2
#
#    GenreId                                           Composer  Milliseconds  \
# 0        1          Angus Young, Malcolm Young, Brian Johnson        343719
# 1        1                                               None        342562
# 2        1  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 3        1  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# 4        1                         Deaffy & R.A. Smith-Diesel        375418
#
#       Bytes  UnitPrice
# 0  11170334       0.99
# ...

# %%
query = "SELECT * FROM playlists LIMIT 5;"
# Use the get_connection method to access the underlying connection
with db._engine.connect() as conn:
    df = pd.read_sql_query(query, conn)
df
# Out:
#    PlaylistId        Name
# 0           1       Music
# 1           2      Movies
# 2           3    TV Shows
# 3           4  Audiobooks
# 4           5  90’s Music

# %%
query = "SELECT * FROM playlist_track LIMIT 5;"
# Use the get_connection method to access the underlying connection
with db._engine.connect() as conn:
    df = pd.read_sql_query(query, conn)
df
# Out:
#    PlaylistId  TrackId
# 0           1     3402
# 1           1     3389
# 2           1     3390
# 3           1     3391
# 4           1     3392
